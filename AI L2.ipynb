# %% [markdown]
# ## Topic 1: Classes & Objects
# ### Q1: Create a class Dog with attributes name and age, then create two dog objects.

# %%
class Dog:
    def __init__(self, name, age):
        self.name = name
        self.age = age

dog1 = Dog("Buddy", 3)
dog2 = Dog("Max", 5)
print(f"{dog1.name} is {dog1.age} years old")
print(f"{dog2.name} is {dog2.age} years old")
# Out:
# Buddy is 3 years old
# Max is 5 years old

# %% [markdown]
# ### Q2: Create a Book class with title and author attributes. Add a method to display book info.

# %%
class Book:
    def __init__(self, title, author):
        self.title = title
        self.author = author
    
    def display_info(self):
        return f"'{self.title}' by {self.author}"

book1 = Book("1984", "George Orwell")
print(book1.display_info())
# Out:
# '1984' by George Orwell

# %% [markdown]
# ### Q3: Create a BankAccount class with balance attribute and methods to deposit/withdraw.

# %%
class BankAccount:
    def __init__(self, initial_balance=0):
        self.balance = initial_balance
    
    def deposit(self, amount):
        self.balance += amount
        return self.balance
    
    def withdraw(self, amount):
        if amount <= self.balance:
            self.balance -= amount
        else:
            print("Insufficient funds")
        return self.balance

account = BankAccount(100)
account.deposit(50)
account.withdraw(30)
print(f"Balance: ${account.balance}")
# Out:
# Balance: $120

# %% [markdown]
# ## Topic 2: Constructors and Instance Methods
# ### Q4: Create a Rectangle class that calculates area and perimeter.

# %%
class Rectangle:
    def __init__(self, length, width):
        self.length = length
        self.width = width
    
    def area(self):
        return self.length * self.width
    
    def perimeter(self):
        return 2 * (self.length + self.width)

rect = Rectangle(5, 3)
print(f"Area: {rect.area()}, Perimeter: {rect.perimeter()}")
# Out:
# Area: 15, Perimeter: 16

# %% [markdown]
# ### Q5: Create a Student class with methods to add grades and calculate average.

# %%
class Student:
    def __init__(self, name):
        self.name = name
        self.grades = []
    
    def add_grade(self, grade):
        self.grades.append(grade)
    
    def average_grade(self):
        if not self.grades:
            return 0
        return sum(self.grades) / len(self.grades)

student = Student("Alice")
student.add_grade(85)
student.add_grade(90)
student.add_grade(78)
print(f"{student.name}'s average: {student.average_grade():.1f}")
# Out:
# Alice's average: 84.3

# %% [markdown]
# ## Topic 3: Class vs Instance Variables
# ### Q6: Create a Employee class with company name as class variable and name as instance variable.

# %%
class Employee:
    company = "TechCorp"  # Class variable
    
    def __init__(self, name):
        self.name = name  # Instance variable
    
    def display(self):
        return f"{self.name} works at {Employee.company}"

emp1 = Employee("John")
emp2 = Employee("Sarah")
print(emp1.display())
print(emp2.display())
# Out:
# John works at TechCorp
# Sarah works at TechCorp

# %% [markdown]
# ### Q7: Create a Car class that tracks how many cars have been created.

# %%
class Car:
    total_cars = 0  # Class variable
    
    def __init__(self, brand, model):
        self.brand = brand
        self.model = model
        Car.total_cars += 1
    
    @classmethod
    def get_total_cars(cls):
        return cls.total_cars

car1 = Car("Toyota", "Camry")
car2 = Car("Honda", "Civic")
car3 = Car("Ford", "Focus")
print(f"Total cars created: {Car.get_total_cars()}")
# Out:
# Total cars created: 3

# %% [markdown]
# ## Topic 4: Getters, Setters, and Properties
# ### Q8: Create a Temperature class with celsius property and fahrenheit getter/setter.

# %%
class Temperature:
    def __init__(self, celsius):
        self._celsius = celsius
    
    @property
    def celsius(self):
        return self._celsius
    
    @celsius.setter
    def celsius(self, value):
        self._celsius = value
    
    @property
    def fahrenheit(self):
        return (self._celsius * 9/5) + 32
    
    @fahrenheit.setter
    def fahrenheit(self, value):
        self._celsius = (value - 32) * 5/9

temp = Temperature(25)
print(f"Celsius: {temp.celsius}, Fahrenheit: {temp.fahrenheit}")
temp.fahrenheit = 77
print(f"After setting 77F -> Celsius: {temp.celsius:.1f}")
# Out:
# Celsius: 25, Fahrenheit: 77.0
# After setting 77F -> Celsius: 25.0

# %% [markdown]
# ### Q9: Create a Person class with age validation using property decorator.

# %%
class Person:
    def __init__(self, name, age):
        self.name = name
        self._age = age
    
    @property
    def age(self):
        return self._age
    
    @age.setter
    def age(self, value):
        if value < 0:
            print("Age cannot be negative!")
        elif value > 150:
            print("Age seems unrealistic!")
        else:
            self._age = value

person = Person("Bob", 30)
person.age = 35  # Valid
person.age = -5  # Invalid
print(f"{person.name} is {person.age} years old")
# Out:
# Age cannot be negative!
# Bob is 35 years old

# %% [markdown]
# ## Topic 5: Inheritance
# ### Q10: Create base class Animal and derived classes Dog and Cat.

# %%
class Animal:
    def __init__(self, name):
        self.name = name
    
    def speak(self):
        return "Some sound"

class Dog(Animal):
    def speak(self):
        return "Woof!"

class Cat(Animal):
    def speak(self):
        return "Meow!"

animals = [Dog("Buddy"), Cat("Whiskers")]
for animal in animals:
    print(f"{animal.name} says: {animal.speak()}")
# Out:
# Buddy says: Woof!
# Whiskers says: Meow!

# %% [markdown]
# ### Q11: Create a Vehicle base class and Car and Motorcycle subclasses.

# %%
class Vehicle:
    def __init__(self, brand, model):
        self.brand = brand
        self.model = model
    
    def display_info(self):
        return f"{self.brand} {self.model}"

class Car(Vehicle):
    def __init__(self, brand, model, doors):
        super().__init__(brand, model)
        self.doors = doors
    
    def display_info(self):
        return f"{super().display_info()} with {self.doors} doors"

class Motorcycle(Vehicle):
    def __init__(self, brand, model, type):
        super().__init__(brand, model)
        self.type = type
    
    def display_info(self):
        return f"{super().display_info()} ({self.type})"

vehicles = [Car("Toyota", "Camry", 4), Motorcycle("Harley", "Sportster", "Cruiser")]
for v in vehicles:
    print(v.display_info())
# Out:
# Toyota Camry with 4 doors
# Harley Sportster (Cruiser)

# %% [markdown]
# ### Q12: Create a base class Shape with abstract area method (using NotImplementedError).

# %%
class Shape:
    def area(self):
        raise NotImplementedError("Subclass must implement area()")

class Circle(Shape):
    def __init__(self, radius):
        self.radius = radius
    
    def area(self):
        return 3.14159 * self.radius ** 2

class Square(Shape):
    def __init__(self, side):
        self.side = side
    
    def area(self):
        return self.side ** 2

shapes = [Circle(5), Square(4)]
for shape in shapes:
    print(f"Area: {shape.area():.2f}")
# Out:
# Area: 78.54
# Area: 16.00

# %% [markdown]
# ## Topic 6: Multiple Inheritance & Method Resolution Order (MRO)
# ### Q13: Create two parent classes and a child class that inherits from both.

# %%
class Engine:
    def start(self):
        return "Engine started"

class ElectricSystem:
    def charge(self):
        return "Battery charging"

class HybridCar(Engine, ElectricSystem):
    def __init__(self, model):
        self.model = model
    
    def display(self):
        return f"{self.model}: {self.start()} and {self.charge()}"

car = HybridCar("Prius")
print(car.display())
print(f"MRO: {HybridCar.__mro__}")
# Out:
# Prius: Engine started and Battery charging
# MRO: (<class '__main__.HybridCar'>, <class '__main__.Engine'>, <class '__main__.ElectricSystem'>, <class 'object'>)

# %% [markdown]
# ## Topic 7: Special/Magic Methods
# ### Q14: Implement __str__ and __repr__ methods for a Book class.

# %%
class Book:
    def __init__(self, title, author, year):
        self.title = title
        self.author = author
        self.year = year
    
    def __str__(self):
        return f"'{self.title}' by {self.author}"
    
    def __repr__(self):
        return f"Book('{self.title}', '{self.author}', {self.year})"

book = Book("To Kill a Mockingbird", "Harper Lee", 1960)
print(str(book))    # User-friendly
print(repr(book))   # Developer-friendly
# Out:
# 'To Kill a Mockingbird' by Harper Lee
# Book('To Kill a Mockingbird', 'Harper Lee', 1960)

# %% [markdown]
# ### Q15: Implement __add__ method for a Vector class.

# %%
class Vector:
    def __init__(self, x, y):
        self.x = x
        self.y = y
    
    def __add__(self, other):
        return Vector(self.x + other.x, self.y + other.y)
    
    def __str__(self):
        return f"Vector({self.x}, {self.y})"

v1 = Vector(2, 3)
v2 = Vector(4, 5)
v3 = v1 + v2
print(v3)  # Vector(6, 8)
# Out:
# Vector(6, 8)

# %% [markdown]
# ### Q16. Implement __len__ and __getitem__ for a custom collection class.

# %%
class Playlist:
    def __init__(self, songs):
        self.songs = songs
    
    def __len__(self):
        return len(self.songs)
    
    def __getitem__(self, index):
        return self.songs[index]

playlist = Playlist(["Song1", "Song2", "Song3", "Song4"])
print(f"Playlist length: {len(playlist)}")
print(f"First song: {playlist[0]}")
print(f"Last song: {playlist[-1]}")
# Out:
# Playlist length: 4
# First song: Song1
# Last song: Song4

# %% [markdown]
# ## Topic 8: Class Methods and Static Methods
# ### Q17: Create a class with class method and static method.

# %%
class MathOperations:
    PI = 3.14159
    
    @classmethod
    def circle_area(cls, radius):
        return cls.PI * radius ** 2
    
    @staticmethod
    def add(a, b):
        return a + b
    
    @staticmethod
    def is_even(number):
        return number % 2 == 0

print(f"Circle area: {MathOperations.circle_area(5):.2f}")
print(f"Sum: {MathOperations.add(10, 20)}")
print(f"Is 7 even? {MathOperations.is_even(7)}")
# Out:
# Circle area: 78.54
# Sum: 30
# Is 7 even? False

# %% [markdown]
# ## Topic 9: Encapsulation and Private Members
# ### Q18: Create a class with private attributes and getter/setter methods.

# %%
class BankAccount:
    def __init__(self, account_holder, balance):
        self.account_holder = account_holder
        self.__balance = balance  # Private attribute
    
    def deposit(self, amount):
        if amount > 0:
            self.__balance += amount
        return self.__balance
    
    def withdraw(self, amount):
        if 0 < amount <= self.__balance:
            self.__balance -= amount
        else:
            print("Invalid withdrawal amount")
        return self.__balance
    
    def get_balance(self):
        return self.__balance

account = BankAccount("Alice", 1000)
account.deposit(500)
account.withdraw(200)
print(f"Balance: ${account.get_balance()}")
# print(account.__balance)  # This would cause an error
# Out:
# Balance: $1300

# %% [markdown]
# ## Topic 10: Polymorphism
# ### Q19: Demonstrate polymorphism with different shape classes.

# %%
class Rectangle:
    def __init__(self, width, height):
        self.width = width
        self.height = height
    
    def area(self):
        return self.width * self.height

class Triangle:
    def __init__(self, base, height):
        self.base = base
        self.height = height
    
    def area(self):
        return 0.5 * self.base * self.height

def print_area(shape):
    print(f"Area: {shape.area()}")

rect = Rectangle(4, 5)
tri = Triangle(4, 5)
print_area(rect)
print_area(tri)
# Out:
# Area: 20
# Area: 10.0

# %% [markdown]
# ## Topic 11: Composition
# ### Q20: Create a Library class that contains multiple Book objects.

# %%
class Book:
    def __init__(self, title, author):
        self.title = title
        self.author = author

class Library:
    def __init__(self):
        self.books = []
    
    def add_book(self, book):
        self.books.append(book)
    
    def list_books(self):
        for book in self.books:
            print(f"'{book.title}' by {book.author}")

library = Library()
library.add_book(Book("1984", "George Orwell"))
library.add_book(Book("Brave New World", "Aldous Huxley"))
library.list_books()
# Out:
# '1984' by George Orwell
# 'Brave New World' by Aldous Huxley
