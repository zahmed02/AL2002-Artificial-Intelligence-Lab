# %%
# Create a simple DataFrame
df = pd.DataFrame({
    'A': [1, 2, 3, 4],
    'B': [5, 6, 7, 8]
})
print(df)
# Out:
#    A  B
# 0  1  5
# 1  2  6
# 2  3  7
# 3  4  8

# %%
# Create and manipulate numpy array
arr = np.array([1, 2, 3, 4, 5])
print(f"Array: {arr}")
print(f"Mean: {np.mean(arr)}")
# Out:
# Array: [1 2 3 4 5]
# Mean: 3.0

# %%
# Basic line plot
x = [1, 2, 3, 4, 5]
y = [2, 4, 6, 8, 10]
plt.plot(x, y)
plt.title("Simple Line Plot")
plt.show()

# %%
# Add new column and filter
df['C'] = df['A'] + df['B']
filtered = df[df['A'] > 2]
print(filtered)
# Out:
#    A  B   C
# 2  3  7  10
# 3  4  8  12

# %%
# Generate random data
random_data = np.random.randn(100)  # 100 random numbers
plt.hist(random_data, bins=20)
plt.title("Random Data Histogram")
plt.show()

# %%
# Create scatter plot
x = np.random.rand(50)
y = np.random.rand(50)
plt.scatter(x, y)
plt.title("Random Scatter Plot")
plt.show()

# %%
# Calculate basic statistics
print("DataFrame Info:")
print(df.info())
print("\nDescriptive Statistics:")
print(df.describe())
# Out:
# DataFrame Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   A       4 non-null      int64
#  1   B       4 non-null      int64
#  2   C       4 non-null      int64
# dtypes: int64(3)
# memory usage: 228.0 bytes
# None
#
# Descriptive Statistics:
#               A         B          C
# count  4.000000  4.000000   4.000000
# mean   2.500000  6.500000   9.000000
# std    1.290994  1.290994   2.581989
# min    1.000000  5.000000   6.000000
# 25%    1.750000  5.750000   7.500000
# 50%    2.500000  6.500000   9.000000
# 75%    3.250000  7.250000  10.500000
# max    4.000000  8.000000  12.000000
